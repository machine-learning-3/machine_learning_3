# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

import torchvision
import torchvision.datasets
import torchvision.transforms as transforms

import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
from torchsummary import summary
import time
import copy

import random

import os

# %%
from torchvision import datasets as ds
from torch.utils.data import DataLoader
from torchvision import transforms as ts
import torchvision as tv
import torch
import torch.nn as nn
import math
import numpy as np
from torch.autograd import Variable
from torch import optim
from matplotlib import pyplot as plt
import torch.backends.cudnn as cudnn
from PIL import Image
from tqdm import tqdm
import random
import os

# %config Completer.use_jedi = False

# %%
class config:
    seed = 42
    device = "cuda:0"    
        
    lr = 1e-3
    epochs = 25
    batch_size = 32
    num_workers = 4
    train_5_folds = True

def seed_everything(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)  # type: ignore
    torch.backends.cudnn.deterministic = True  # type: ignore
    torch.backends.cudnn.benchmark = True  # type: ignore

seed_everything(config.seed)

# %%
  transform = ts.Compose(
      [
          ts.ToTensor(),
          ts.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
      ]
  )

# %%
trainset = torchvision.datasets.CIFAR10(root='/content/drive/MyDrive/share/cafir_10',
                                        train=True,
                                        download=True,
                                        transform=transform)

vaildset = torchvision.datasets.CIFAR10(root='/content/drive/MyDrive/share/cafir_10',
                                        train=False,
                                        download=True,
                                        transform=transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
testset = torchvision.datasets.ImageFolder(root = "C:/Users/fkrdn/Desktop/Statistical_Deep_Image",
                                           transform = transform)

# %%
train_loader = DataLoader(trainset,
                          batch_size = 32,
                          shuffle=True,
                          num_workers=2)

vaild_loader = DataLoader(vaildset,
                          batch_size = 32,
                          shuffle=True,
                          num_workers=2)


test_loader = DataLoader(testset,
                          batch_size=32,
                          shuffle=False,
                          num_workers=2)

# %%
class BottleNeck(nn.Module):
    def __init__(self, in_channels, growth_rate):
        super().__init__()
        inner_channels = 4 * growth_rate

        self.residual = nn.Sequential(
            nn.BatchNorm2d(in_channels),
            nn.ReLU(),
            nn.Conv2d(in_channels, inner_channels, 1, stride=1, padding=0, bias=False),
            nn.BatchNorm2d(inner_channels),
            nn.ReLU(),
            nn.Conv2d(inner_channels, growth_rate, 3, stride=1, padding=1, bias=False)
        )

        self.shortcut = nn.Sequential()

    def forward(self, x):
        return torch.cat([self.shortcut(x), self.residual(x)], 1)

# %%
class Transition(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()

        self.down_sample = nn.Sequential(
            nn.BatchNorm2d(in_channels),
            nn.ReLU(),
            nn.Conv2d(in_channels, out_channels, 1, stride=1, padding=0, bias=False),
            nn.AvgPool2d(2, stride=2)
        )

    def forward(self, x):
        return self.down_sample(x)

# %%
class DenseNet(nn.Module):
    def __init__(self, nblocks, growth_rate=12, reduction=0.5, num_classes=10, init_weights=True):
        super().__init__()

        self.growth_rate = growth_rate
        inner_channels = 2 * growth_rate # output channels of conv1 before entering Dense Block

        self.conv1 = nn.Sequential(
            nn.Conv2d(3, inner_channels, 5, stride=1, padding=1),
            nn.MaxPool2d(3, 2, padding=1)
        )

        self.features = nn.Sequential()

        for i in range(len(nblocks)-1):
            self.features.add_module('dense_block_{}'.format(i), self._make_dense_block(nblocks[i], inner_channels))
            inner_channels += growth_rate * nblocks[i]
            out_channels = int(reduction * inner_channels)
            self.features.add_module('transition_layer_{}'.format(i), Transition(inner_channels, out_channels))
            inner_channels = out_channels 
        
        self.features.add_module('dense_block_{}'.format(len(nblocks)-1), self._make_dense_block(nblocks[len(nblocks)-1], inner_channels))
        inner_channels += growth_rate * nblocks[len(nblocks)-1]
        self.features.add_module('bn', nn.BatchNorm2d(inner_channels))
        self.features.add_module('relu', nn.ReLU())

        self.avg_pool = nn.AdaptiveAvgPool2d((1,1))
        self.linear = nn.Linear(inner_channels, num_classes)

        # weight initialization
        if init_weights:
            self._initialize_weights()
    
    def forward(self, x):
        x = self.conv1(x)
        x = self.features(x)
        x = self.avg_pool(x)
        x = x.view(x.size(0), -1)
        x = self.linear(x)
        return x

    def _make_dense_block(self, nblock, inner_channels):
        dense_block = nn.Sequential()
        for i in range(nblock):
            dense_block.add_module('bottle_neck_layer_{}'.format(i), BottleNeck(inner_channels, self.growth_rate))
            inner_channels += self.growth_rate
        return dense_block

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, 0, 0.01)
                nn.init.constant_(m.bias, 0)

def DenseNet_121():
    return DenseNet([6, 12, 24, 6])

# %%
model = DenseNet_121()

# %%
use_cuda = torch.cuda.is_available()

device = torch.device("cuda" if use_cuda else "cpu")

device
# Out:
# device(type='cpu')

# %%
model = model.to(device)

# %%
loss_func = nn.CrossEntropyLoss(reduction='sum')
opt = optim.Adam(model.parameters(), lr=0.01)

from torch.optim.lr_scheduler import ReduceLROnPlateau
lr_scheduler = ReduceLROnPlateau(opt, mode='min', factor=0.1, patience=8)


# get current lr
def get_lr(opt):
    for param_group in opt.param_groups:
        return param_group['lr']


# calculate the metric per mini-batch
def metric_batch(output, target):
    pred = output.argmax(1, keepdim=True)
    corrects = pred.eq(target.view_as(pred)).sum().item()
    return corrects


# calculate the loss per mini-batch
def loss_batch(loss_func, output, target, opt=None):
    loss_b = loss_func(output, target)
    metric_b = metric_batch(output, target)

    if opt is not None:
        opt.zero_grad()
        loss_b.backward()
        opt.step()
    
    return loss_b.item(), metric_b


# calculate the loss per epochs
def loss_epoch(model, loss_func, dataset_dl, sanity_check=False, opt=None):
    running_loss = 0.0
    running_metric = 0.0
    len_data = len(dataset_dl.dataset)

    for xb, yb in dataset_dl:
        xb = xb.to(device)
        yb = yb.to(device)
        output = model(xb)

        loss_b, metric_b = loss_batch(loss_func, output, yb, opt)

        running_loss += loss_b
        
        if metric_b is not None:
            running_metric += metric_b

        if sanity_check is True:
            break

    loss = running_loss / len_data
    metric = running_metric / len_data
    return loss, metric


# function to start training
def train_val(model, params):
    num_epochs=params['num_epochs']
    loss_func=params['loss_func']
    opt=params['optimizer']
    train_dl=params['train_dl']
    val_dl=params['val_dl']
    sanity_check=params['sanity_check']
    lr_scheduler=params['lr_scheduler']
    path2weights=params['path2weights']

    loss_history = {'train': [], 'val': []}
    metric_history = {'train': [], 'val': []}

    best_loss = float('inf')
    best_model_wts = copy.deepcopy(model.state_dict())
    start_time = time.time()

    for epoch in range(num_epochs):
        current_lr = get_lr(opt)
        print('Epoch {}/{}, current lr= {}'.format(epoch, num_epochs-1, current_lr))

        model.train()
        train_loss, train_metric = loss_epoch(model, loss_func, train_dl, sanity_check, opt)
        loss_history['train'].append(train_loss)
        metric_history['train'].append(train_metric)

        model.eval()
        with torch.no_grad():
            val_loss, val_metric = loss_epoch(model, loss_func, val_dl, sanity_check)
        loss_history['val'].append(val_loss)
        metric_history['val'].append(val_metric)

        if val_loss < best_loss:
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            torch.save(model.state_dict(), path2weights)
            print('Copied best model weights!')

        lr_scheduler.step(val_loss)
        if current_lr != get_lr(opt):
            print('Loading best model weights!')
            model.load_state_dict(best_model_wts)

        print('train loss: %.6f, val loss: %.6f, accuracy: %.2f, time: %.4f min' %(train_loss, val_loss, 100*val_metric, (time.time()-start_time)/60))
        print('-'*10)

    model.load_state_dict(best_model_wts)
    return model, loss_history, metric_history

# %%
params_train = {
    'num_epochs':40,
    'optimizer':opt,
    'loss_func':loss_func,
    'train_dl':train_loader,
    'val_dl':vaild_loader,
    'sanity_check':False,
    'lr_scheduler':lr_scheduler,
    'path2weights':'./models_densenet_54_2/weights.pt',
}

# check the directory to save weights.pt
def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSerror:
        print('Error')
createFolder('./models_densenet_54_2')

# %%
model, loss_hist, metric_hist = train_val(model, params_train)
# Out:
# Epoch 0/39, current lr= 0.01
# Copied best model weights!
# train loss: 1.512673, val loss: 1.126757, accuracy: 59.24, time: 6.1190 min
# ----------
# Epoch 1/39, current lr= 0.01
# Copied best model weights!
# train loss: 1.068576, val loss: 0.990357, accuracy: 65.59, time: 12.3068 min
# ----------
# Epoch 2/39, current lr= 0.01
# Copied best model weights!
# train loss: 0.880839, val loss: 0.791501, accuracy: 72.43, time: 18.7248 min
# ----------
# Epoch 3/39, current lr= 0.01
# Copied best model weights!
# train loss: 0.757370, val loss: 0.771136, accuracy: 72.81, time: 25.1239 min
# ----------
# Epoch 4/39, current lr= 0.01
# Copied best model weights!
# train loss: 0.670223, val loss: 0.694438, accuracy: 75.87, time: 31.4891 min
# ----------
# Epoch 5/39, current lr= 0.01
# Copied best model weights!
# train loss: 0.601546, val loss: 0.625021, accuracy: 78.51, time: 37.8815 min
# ----------
# Epoch 6/39, current lr= 0.01
# Copied best model weights!
# train loss: 0.546826, val loss: 0.617250, accuracy: 79.11, time: 44.1833 min
# ----------
# Epoch 7/39, current lr= 0.01
# train loss: 0.498403, val loss: 0.633621, accuracy: 78.98, time: 50.5077 min
# ----------
# Epoch 8/39, current lr= 0.01
# train loss: 0.450023, val loss: 0.623044, accuracy: 78.88, time: 56.7500 min
# ----------
# Epoch 9/39, current lr= 0.01
# Copied best model weights!
# train loss: 0.418702, val loss: 0.604729, accuracy: 80.00, time: 63.0667 min
# ----------
# Epoch 10/39, current lr= 0.01
# Copied best model weights!
# train loss: 0.378906, val loss: 0.604581, accuracy: 80.21, time: 69.3993 min
# ----------
# Epoch 11/39, current lr= 0.01
# Copied best model weights!
# train loss: 0.347668, val loss: 0.603766, accuracy: 80.73, time: 75.6904 min
# ----------
# Epoch 12/39, current lr= 0.01
# train loss: 0.318540, val loss: 0.647232, accuracy: 79.92, time: 81.8880 min
# ----------
# Epoch 13/39, current lr= 0.01
# train loss: 0.292154, val loss: 0.669680, accuracy: 79.82, time: 87.9466 min
# ----------
# Epoch 14/39, current lr= 0.01
# train loss: 0.267968, val loss: 0.662200, accuracy: 80.20, time: 94.0500 min
# ----------
# Epoch 15/39, current lr= 0.01
# train loss: 0.251411, val loss: 0.650744, accuracy: 80.49, time: 100.1776 min
# ----------
# Epoch 16/39, current lr= 0.01
# train loss: 0.235358, val loss: 0.664675, accuracy: 80.78, time: 106.2568 min
# ----------
# Epoch 17/39, current lr= 0.01
# train loss: 0.219798, val loss: 0.669985, accuracy: 81.23, time: 112.3553 min
# ----------
# Epoch 18/39, current lr= 0.01
# train loss: 0.204557, val loss: 0.717561, accuracy: 81.11, time: 118.4046 min
# ----------
# Epoch 19/39, current lr= 0.01
# train loss: 0.186927, val loss: 0.734879, accuracy: 80.58, time: 124.5310 min
# ----------
# Epoch 20/39, current lr= 0.01
# Loading best model weights!
# train loss: 0.181423, val loss: 0.716489, accuracy: 80.53, time: 130.6708 min
# ----------
# Epoch 21/39, current lr= 0.001
# Copied best model weights!
# train loss: 0.191437, val loss: 0.593483, accuracy: 82.72, time: 136.7846 min
# ----------
# Epoch 22/39, current lr= 0.001
# train loss: 0.139164, val loss: 0.654338, accuracy: 82.70, time: 142.9058 min
# ----------
# Epoch 23/39, current lr= 0.001
# train loss: 0.109878, val loss: 0.695438, accuracy: 83.26, time: 148.8741 min
# ----------
# Epoch 24/39, current lr= 0.001
# train loss: 0.091704, val loss: 0.734929, accuracy: 82.59, time: 154.9865 min
# ----------
# Epoch 25/39, current lr= 0.001
# train loss: 0.076732, val loss: 0.786711, accuracy: 82.23, time: 161.1158 min
# ----------
# Epoch 26/39, current lr= 0.001
# train loss: 0.066572, val loss: 0.834910, accuracy: 82.16, time: 167.1517 min
# ----------
# Epoch 27/39, current lr= 0.001
# train loss: 0.056908, val loss: 0.869986, accuracy: 82.35, time: 173.1948 min
# ----------
# Epoch 28/39, current lr= 0.001
# train loss: 0.049781, val loss: 0.921140, accuracy: 82.09, time: 179.1036 min
# ----------
# Epoch 29/39, current lr= 0.001
# train loss: 0.045893, val loss: 0.957591, accuracy: 81.97, time: 185.1334 min
# ----------
# Epoch 30/39, current lr= 0.001
# Loading best model weights!
# train loss: 0.038313, val loss: 1.003359, accuracy: 82.16, time: 191.1875 min
# ----------
# Epoch 31/39, current lr= 0.0001
# train loss: 0.137506, val loss: 0.614907, accuracy: 82.74, time: 197.2355 min
# ----------
# Epoch 32/39, current lr= 0.0001
# train loss: 0.130297, val loss: 0.605980, accuracy: 82.98, time: 203.2872 min
# ----------
# Epoch 33/39, current lr= 0.0001
# train loss: 0.125662, val loss: 0.612245, accuracy: 82.95, time: 209.2873 min
# ----------
# Epoch 34/39, current lr= 0.0001
# train loss: 0.121381, val loss: 0.614411, accuracy: 83.09, time: 215.3367 min
# ----------
# Epoch 35/39, current lr= 0.0001
# train loss: 0.117589, val loss: 0.626299, accuracy: 82.91, time: 221.3758 min
# ----------
# Epoch 36/39, current lr= 0.0001
# train loss: 0.112373, val loss: 0.633445, accuracy: 82.95, time: 227.3940 min
# ----------
# Epoch 37/39, current lr= 0.0001
# train loss: 0.110738, val loss: 0.649279, accuracy: 83.07, time: 233.4496 min
# ----------
# Epoch 38/39, current lr= 0.0001
# train loss: 0.109483, val loss: 0.651691, accuracy: 83.05, time: 239.4855 min
# ----------
# Epoch 39/39, current lr= 0.0001
# Loading best model weights!
# train loss: 0.104140, val loss: 0.658473, accuracy: 82.92, time: 245.5344 min
# ----------

# %%
model.load_state_dict(torch.load('models_densenet_54_2/weights.pt'))
# Out:
# <All keys matched successfully>

# %%
model.eval()
# Out:
# DenseNet(
#   (conv1): Sequential(
#     (0): Conv2d(3, 24, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#     (1): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (features): Sequential(
#     (dense_block_0): Sequential(
#       (bottle_neck_layer_0): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(24, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_1): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(36, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_2): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_3): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(60, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_4): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(72, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_5): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(84, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(84, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#     )
#     (transition_layer_0): Transition(
#       (down_sample): Sequential(
#         (0): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU()
#         (2): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#     )
#     (dense_block_1): Sequential(
#       (bottle_neck_layer_0): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_1): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(60, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_2): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(72, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_3): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(84, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(84, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_4): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_5): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(108, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_6): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(120, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_7): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(132, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(132, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_8): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(144, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_9): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(156, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_10): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(168, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_11): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(180, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#     )
#     (transition_layer_1): Transition(
#       (down_sample): Sequential(
#         (0): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU()
#         (2): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#     )
#     (dense_block_2): Sequential(
#       (bottle_neck_layer_0): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_1): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(108, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_2): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(120, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_3): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(132, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(132, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_4): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(144, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_5): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(156, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_6): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(168, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_7): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(180, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_8): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_9): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(204, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(204, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_10): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(216, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_11): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(228, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(228, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_12): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(240, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_13): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(252, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(252, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_14): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(264, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(264, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_15): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(276, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(276, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_16): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_17): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(300, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_18): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(312, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(312, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_19): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(324, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(324, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_20): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(336, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_21): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(348, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(348, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_22): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(360, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(360, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_23): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(372, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(372, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#     )
#     (transition_layer_2): Transition(
#       (down_sample): Sequential(
#         (0): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU()
#         (2): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#     )
#     (dense_block_3): Sequential(
#       (bottle_neck_layer_0): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_1): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(204, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(204, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_2): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(216, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_3): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(228, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(228, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_4): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(240, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#       (bottle_neck_layer_5): BottleNeck(
#         (residual): Sequential(
#           (0): BatchNorm2d(252, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU()
#           (2): Conv2d(252, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): ReLU()
#           (5): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (shortcut): Sequential()
#       )
#     )
#     (bn): BatchNorm2d(264, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (linear): Linear(in_features=264, out_features=10, bias=True)
# )

# %%
total = 0
correct = 0
with torch.no_grad():
    for data in test_loader:
      images, labels = data[0].to(device), data[1].to(device)
      outputs= model(images)
      _, predicted = torch.max(outputs.data,1)
      total +=labels.size(0)
      correct += (predicted == labels).sum().item()

print(100* correct/total)
# Out:
# 54.42278860569715
